# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Fundamentos de Aprendizado de Máquina
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Teoria;</li>
#   <li>Atributos categóricos;</li>
#   <li>Atributos numéricos;</li>
#   <li>Dados faltantes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Pinguins

# %% [markdown]
# Neste exercício, vamos utilizar uma base de dados com informações sobre penguins. A idéia é preparar a base de dados para prever a espécie do penguin (variável resposta) baseado em suas características físicas e geográficas (variáveis preditivas).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re

# %%
data = sns.load_dataset('penguins')

# %%
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **1.1. Valores nulos**

# %% [markdown]
# A base de dados possui valores faltantes, utilize os conceitos da aula para trata-los.

# %%
# resposta da questão 1.1

# %%
data[['species', 'island', 'sex']].isnull().any()
# Out:
# species    False
# island     False
# sex         True
# dtype: bool

# %%
data_clean = data.dropna(subset='sex')
data_clean[['species', 'island', 'sex']].isnull().any()
# Out:
# species    False
# island     False
# sex        False
# dtype: bool

# %%
data_clean[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].isnull().any()
# Out:
# bill_length_mm       False
# bill_depth_mm        False
# flipper_length_mm    False
# body_mass_g          False
# dtype: bool

# %% [markdown]
# ### **1.2. Variáveis numéricas**

# %% [markdown]
# Identifique as variáveis numéricas e crie uma nova coluna **padronizando** seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_std*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.2


std_df = data_clean[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]


std_df = std_df.apply(lambda x: (x - np.mean(x)) / np.std(x))


std_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm   body_mass_g
# count    3.330000e+02   3.330000e+02       3.330000e+02  3.330000e+02
# mean     3.840772e-16   6.401286e-16       2.133762e-16 -1.707010e-16
# std      1.001505e+00   1.001505e+00       1.001505e+00  1.001505e+00
# min     -2.177987e+00  -2.067291e+00      -2.069852e+00 -1.874435e+00
# 25%     -8.227879e-01  -7.958519e-01      -7.836512e-01 -8.172292e-01
# 50%      9.288742e-02   6.872642e-02      -2.834620e-01 -1.953432e-01
# 75%      8.437412e-01   7.807321e-01       8.598276e-01  7.063915e-01
# max      2.858227e+00   2.204743e+00       2.146028e+00  2.603144e+00

# %%
# Renomeando as colunas
for col in std_df:
  std_df.rename(columns={col: col + '_std'}, inplace=True)

# %%
# Mesclando com o DataFrame original
data_clean = pd.merge(left = data_clean, right = std_df, how = 'inner', right_index= True, left_index= True)

# %%
data_clean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_length_mm_std_x  bill_depth_mm_std_x  \
# 0       3750.0    Male             -0.896042             0.780732
# 1       3800.0  Female             -0.822788             0.119584
# 2       3250.0  Female             -0.676280             0.424729
# 4       3450.0  Female             -1.335566             1.085877
# 5       3650.0    Male             -0.859415             1.747026
#
#    flipper_length_mm_std_x  body_mass_g_std_x  bill_length_mm_std_y  \
# 0                -1.426752          -0.568475             -0.896042
# 1                -1.069474          -0.506286             -0.822788
# 2                -0.426373          -1.190361             -0.676280
# 4                -0.569284          -0.941606             -1.335566
# 5                -0.783651          -0.692852             -0.859415
#
#    bill_depth_mm_std_y  flipper_length_mm_std_y  body_mass_g_std_y
# 0             0.780732                -1.426752          -0.568475
# 1             0.119584                -1.069474          -0.506286
# 2             0.424729                -0.426373          -1.190361
# 4             1.085877                -0.569284          -0.941606
# 5             1.747026                -0.783651          -0.692852

# %% [markdown]
# ### **1.3. Variáveis categóricas**

# %% [markdown]
# Identifique as variáveis categóricas nominais e ordinais, crie uma nova coluna aplicando a técnica correta de conversão a seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_nom*" ou "*_ord*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.3

# %%
nom_df = pd.get_dummies(data= data_clean[['island', 'sex']])


for col in nom_df:
  nom_df.rename(columns={col: col + '_ord'}, inplace=True)

# %%
data_clean = pd.merge(left = data_clean, right = nom_df, how = 'inner', right_index= True, left_index= True)

data_clean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  bill_length_mm_std_x  bill_depth_mm_std_x  \
# 0         3750.0    Male             -0.896042             0.780732
# 1         3800.0  Female             -0.822788             0.119584
# 2         3250.0  Female             -0.676280             0.424729
# 4         3450.0  Female             -1.335566             1.085877
# 5         3650.0    Male             -0.859415             1.747026
# ..           ...     ...                   ...                  ...
# 338       4925.0  Female              0.587352            -1.762145
# 340       4850.0  Female              0.514098            -1.457000
# 341       5750.0    Male              1.173384            -0.744994
# 342       5200.0  Female              0.221082            -1.202712
# 343       5400.0    Male              1.081817            -0.541564
#
#      flipper_length_mm_std_x  body_mass_g_std_x  bill_length_mm_std_y  \
# 0                  -1.426752          -0.568475             -0.896042
# 1                  -1.069474          -0.506286             -0.822788
# 2                  -0.426373          -1.190361             -0.676280
# 4                  -0.569284          -0.941606             -1.335566
# 5                  -0.783651          -0.692852             -0.859415
# ..                       ...                ...                   ...
# 338                 0.931283           0.892957              0.587352
# 340                 1.002739           0.799674              0.514098
# 341                 1.502928           1.919069              1.173384
# 342                 0.788372           1.234995              0.221082
# 343                 0.859828           1.483749              1.081817
#
#      bill_depth_mm_std_y  flipper_length_mm_std_y  body_mass_g_std_y  \
# 0               0.780732                -1.426752          -0.568475
# 1               0.119584                -1.069474          -0.506286
# 2               0.424729                -0.426373          -1.190361
# 4               1.085877                -0.569284          -0.941606
# 5               1.747026                -0.783651          -0.692852
# ..                   ...                      ...                ...
# 338            -1.762145                 0.931283           0.892957
# 340            -1.457000                 1.002739           0.799674
# 341            -0.744994                 1.502928           1.919069
# 342            -1.202712                 0.788372           1.234995
# 343            -0.541564                 0.859828           1.483749
#
#      island_Biscoe_ord  island_Dream_ord  island_Torgersen_ord  \
# 0                False             False                  True
# 1                False             False                  True
# 2                False             False                  True
# 4                False             False                  True
# 5                False             False                  True
# ..                 ...               ...                   ...
# 338               True             False                 False
# 340               True             False                 False
# 341               True             False                 False
# 342               True             False                 False
# 343               True             False                 False
#
#      sex_Female_ord  sex_Male_ord
# 0             False          True
# 1              True         False
# 2              True         False
# 4              True         False
# 5             False          True
# ..              ...           ...
# 338            True         False
# 340            True         False
# 341           False          True
# 342            True         False
# 343           False          True
#
# [333 rows x 20 columns]

# %% [markdown]
# ### **1.4. Limpeza**

# %% [markdown]
# Descarte as colunas originais e mantenha apenas a variável resposta e as variáveis preditivas com o sufixo *_std*", *_nom*" e "*_ord*".

# %%
# resposta da questão 1.4
columns_list = ['species']
for col in data_clean:
  if re.findall(".*_std.*|.*_ord.*", col):
    columns_list.append(col)
penguins_df = data_clean[columns_list]

penguins_df.head()
# Out:
#   species  bill_length_mm_std_x  bill_depth_mm_std_x  flipper_length_mm_std_x  \
# 0  Adelie             -0.896042             0.780732                -1.426752
# 1  Adelie             -0.822788             0.119584                -1.069474
# 2  Adelie             -0.676280             0.424729                -0.426373
# 4  Adelie             -1.335566             1.085877                -0.569284
# 5  Adelie             -0.859415             1.747026                -0.783651
#
#    body_mass_g_std_x  bill_length_mm_std_y  bill_depth_mm_std_y  \
# 0          -0.568475             -0.896042             0.780732
# 1          -0.506286             -0.822788             0.119584
# 2          -1.190361             -0.676280             0.424729
# 4          -0.941606             -1.335566             1.085877
# 5          -0.692852             -0.859415             1.747026
#
#    flipper_length_mm_std_y  body_mass_g_std_y  island_Biscoe_ord  \
# 0                -1.426752          -0.568475              False
# 1                -1.069474          -0.506286              False
# 2                -0.426373          -1.190361              False
# 4                -0.569284          -0.941606              False
# 5                -0.783651          -0.692852              False
#
#    island_Dream_ord  island_Torgersen_ord  sex_Female_ord  sex_Male_ord
# 0             False                  True           False          True
# 1             False                  True            True         False
# 2             False                  True            True         False
# 4             False                  True            True         False
# 5             False                  True           False          True

# %% [markdown]
# ---
